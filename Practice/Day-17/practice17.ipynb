# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Using cached lxml-6.0.2-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 929.6 kB/s eta 0:00:04
#    ------- -------------------------------- 0.8/4.0 MB 985.5 kB/s eta 0:00:04
#    ---------- ----------------------------- 1.0/4.0 MB 931.8 kB/s eta 0:00:04
#    ---------- ----------------------------- 1.0/4.0 MB 931.8 kB/s eta 0:00:04
#    ------------- -------------------------- 1.3/4.0 MB 944.7 kB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 944.7 kB/s eta 0:00:03
#    --------------- ------------------------ 1.6/4.0 MB 882.6 kB/s eta 0:00:03
#    ------------------ --------------------- 1.8/4.0 MB 853.0 kB/s eta 0:00:03
#    ------------------ --------------------- 1.8/4.0 MB 853.0 kB/s eta 0:00:03
#    -------------------- ------------------- 2.1/4.0 MB 869.7 kB/s eta 0:00:03
#    ----------------------- ---------------- 2.4/4.0 MB 871.3 kB/s eta 0:00:02
#    -------------------------- ------------- 2.6/4.0 MB 877.7 kB/s eta 0:00:02
#    ---------------------------- ----------- 2.9/4.0 MB 901.8 kB/s eta 0:00:02
#    ---------------------------- ----------- 2.9/4.0 MB 901.8 kB/s eta 0:00:02
#    ---------------------------- ----------- 2.9/4.0 MB 901.8 kB/s eta 0:00:02
#    ---------------------------- ----------- 2.9/4.0 MB 901.8 kB/s eta 0:00:02
#    ------------------------------- -------- 3.1/4.0 MB 805.9 kB/s eta 0:00:02
#    --------------------------------- ------ 3.4/4.0 MB 818.3 kB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 838.8 kB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 864.8 kB/s  0:00:05
# Installing collected packages: lxml
# Successfully installed lxml-6.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml
print(lxml.__version__)
# Out:
# 6.0.2

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers = {"User-Agent": "Mozilla/5.0"}

webpage = requests.get(
    "https://www.ambitionbox.com/reviews/tcs-reviews/data-engineer/hyderabad-location",
    headers=headers
).text

soup = BeautifulSoup(webpage, "html.parser")

print(soup.title.text)
# Out:
# TCS Reviews by 100+ Employees | AmbitionBox

# %%
soup.find_all('h1')[0].text
# Out:
# 'TCS Data Engineer Hyderabad Reviews'

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# What employees say about TCS?
# Workplace insights
# Work from office
# Monday to Friday
# Flexible timing
# No travel
# Gender based rating
# Rated by Women
# Rated by Men
# 114 reviews found
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# rated by a Data Engineer in Hyderabad
# TCS Data Engineer Reviews by Locations
# TCS Hyderabad Reviews by Designations

# %%
soup.find_all('p',class_='review')
# Out:
# []
